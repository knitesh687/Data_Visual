# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
da= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/Sep 12/pt1_sandhya.json'))

# %%
data = da.copy()
del data["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/New folder/Sep 12/'+file_name+'.csv')

# %%
df = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/Sep 12/p1.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count  \
# 0                0     0.000    0    0  0.0     0  -1         0
# 1                1     0.400    0    0  0.0     0  -1         0
# 2                2     0.900    0    0  0.0     0  -1         0
# 3                3     0.140    0    0  0.0     0  -1         0
# 4                4     0.190    0    0  0.0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 259411      259411  1297.141   64    0  0.0     0   0        45
# 259412      259412  1297.146   64    0  0.0     0   0        45
# 259413      259413  1297.151   64    0  0.0     0   0        45
# 259414      259414  1297.156   64    0  0.0     0   0        45
# 259415      259415  1297.161   64    0  0.0     0   0        45
#
#         Manual_Uc_Status
# 0                     -1
# 1                     -1
# 2                     -1
# 3                     -1
# 4                     -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259416 entries, 0 to 259415
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        259416 non-null  int64
#  1   index             259416 non-null  float64
#  2   ch1               259416 non-null  int64
#  3   ch2               259416 non-null  int64
#  4   ch3               259416 non-null  float64
#  5   dopp              259416 non-null  int64
#  6   UC                259416 non-null  int64
#  7   UC_count          259416 non-null  int64
#  8   Manual_Uc_Status  259416 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 17.8 MB

# %%
del df['Unnamed: 0']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259416 entries, 0 to 259415
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             259416 non-null  float64
#  1   ch1               259416 non-null  int64
#  2   ch2               259416 non-null  int64
#  3   ch3               259416 non-null  float64
#  4   dopp              259416 non-null  int64
#  5   UC                259416 non-null  int64
#  6   UC_count          259416 non-null  int64
#  7   Manual_Uc_Status  259416 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 15.8 MB

# %%
df.describe()
# Out:
#                index            ch1       ch2            ch3           dopp  \
# count  259416.000000  259416.000000  259416.0  259416.000000  259416.000000
# mean      648.631252      63.101385       0.0    1117.313801      34.767339
# std       374.462571      29.255608       0.0     396.752284     138.212092
# min         0.000000       0.000000       0.0       0.000000       0.000000
# 25%       324.367750      64.000000       0.0     937.000000       0.000000
# 50%       648.617500      64.000000       0.0    1107.000000       0.000000
# 75%       972.885250      81.000000       0.0    1307.000000       0.000000
# max      1297.960000     113.000000       0.0    2732.000000    2642.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  259416.000000  259416.000000     259416.000000
# mean      130.848063      26.127228         -0.816503
# std        48.250034      11.685115          0.577342
# min        -1.000000       0.000000         -1.000000
# ...

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'])
plt.plot(df['Manual_Uc_Status'])
plt.plot(df['UC_count'])
plt.plot(df['index'])
plt.plot(df['dopp'])
#display plot
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'].iloc[:50000])
# plt.plot(df['Manual_Uc_Status'].iloc[:50000])
plt.plot(df['UC_count'].iloc[:50000])
# plt.plot(df['index'])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'].iloc[50000:100000])
plt.plot(df['Manual_Uc_Status'].iloc[50000:100000])
plt.plot(df['UC_count'].iloc[50000:100000])
# plt.plot(df['index'])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'].iloc[100000:110000])
# plt.plot(df['Manual_Uc_Status'].iloc[:50000])
plt.plot(df['UC_count'].iloc[100000:110000])
# plt.plot(df['index'])

plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101000:105000])
plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101500:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101600:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101700:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101800:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101900:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True


plt.plot(df['UC'].iloc[101950:102000])
# plt.plot(df['UC_count'].iloc[101000:105000])


plt.show()

# %%
plt.figure(figsize=(25,16))
x1= df['UC'].iloc[9000:14464]
x2 = df['UC'].iloc[14464:16928]
x3 = df['UC'].iloc[16928:28928]
x4 = df['UC'].iloc[28928:43392]
x5 = df['UC'].iloc[43392:57856]

y1 = df['UC_count'].iloc[9000:14464]
y2 = df['UC_count'].iloc[14464:16928]
y3 = df['UC_count'].iloc[16928:28928]
y4 = df['UC_count'].iloc[28928:43392]
y5 = df['UC_count'].iloc[43392:57856]

plt.plot(x1, 'o')
plt.plot(x2, 'g')
plt.plot(x3, 'y')
plt.plot(x4, 'r')
plt.plot(x5, 'b')

plt.plot(y1, 'o')
plt.plot(y2, 'g')
plt.plot(y3, 'y')
plt.plot(y4, 'r')
plt.plot(y5, 'b')

# %%
fig, ax = plt.subplots(2 , 2 , figsize=(18
                                        ,18))


ax[0, 0].plot(x1, y1, color='r')
ax[0, 1].plot(x2, y2, color='k', linestyle=':')
ax[1, 0].plot(x3, y3, color='y', linestyle='-.')
ax[1, 1].plot(x4, y4, color='c',linestyle='--')
# ax[1, 1].plot(x5, y5, color= 'g', linestyle='--')

# plt.plot(x1, y1, '--')
# plt.plot(y2, x2)
# plt.show()

# %%
plt.title('UC vs UC Count', size = 20)
plt.plot(x1, 'r')
plt.plot(y1, 'g')

# %%
plt.title('UC vs UC Count', size = 20)
plt.plot(x2, 'y')
plt.plot(y2, 'g')

# %%
plt.title('UC vs UC Count', size = 20)
plt.plot(x23, 'g')
plt.plot(y3, 'y')

# %%
plt.title('UC vs UC Count', size = 20)
plt.plot(x3, 'r')
plt.plot(y4, 'b')

# %%
plt.title('UC vs UC Count', size = 20)
plt.plot(x4, 'b')
plt.plot(y5, 'r')

# %%
df.plot.pie(y='UC_count', figsize=(8,8))
